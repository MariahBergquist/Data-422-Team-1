# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
SPD = pd.DataFrame(pd.read_csv("./SPD_2.csv"))

# %%
SPD.isnull().sum()
# Out:
# Date / Time             0
# Longitude               0
# Latitude                0
# City                    0
# Rank                    0
# Officer Gender          0
# Officer Race            0
# Years of SPD Service    0
# Officer Injured         0
# Subject Gender          0
# Subject Race            0
# Subject DOB             0
# Subject Age             0
# Subject Weapon          0
# Type of Weapon          0
# Fatal                   0
# Disposition             0
# Officer Disciplined?    0
# Summary                 0
# dtype: int64

# %%
SPD = SPD.dropna(subset = ['Years of SPD Service','Officer Injured', 'Subject DOB', 'Subject Age', 'Type of Weapon', 'Disposition', 'Officer Disciplined?'])

# %%
SPD
# Out:
#           Date / Time  Longitude  Latitude     City            Rank  \
# 0     3/21/2005 18:28   -122.274    47.544  Seattle         Officer
# 1     6/20/2005 11:30   -122.336    47.615  Seattle         Officer
# 2     6/20/2005 12:30   -122.336    47.615  Seattle         Officer
# 3      7/8/2005 13:48   -122.311    47.613  Seattle         Officer
# 4      9/23/2005 2:40   -122.346    47.612  Seattle         Officer
# ..                ...        ...       ...      ...             ...
# 112  12/31/2018 17:01   -122.345    47.699  Seattle  POLICE OFFICER
# 113  10/24/2019 10:34   -122.387    47.582  Seattle  POLICE OFFICER
# 114  10/24/2019 10:34   -122.387    47.582  Seattle  POLICE OFFICER
# 115   1/22/2020 15:30   -122.344    47.614  Seattle  POLICE OFFICER
# 116    1/22/2020 0:00   -122.344    47.614  Seattle  POLICE OFFICER
#
#     Officer Gender     Officer Race Years of SPD Service Officer Injured  \
# 0             Male            White                   20              No
# ...

# %%
SPD.to_csv('SPD.csv', index=False)

# %%
Crime = pd.DataFrame(pd.read_csv("./SPD_Crime_Data__2008-Present_20241017.csv"))

# %%
Crime.isnull().sum()
# Out:
# Report Number                  0
# Offense ID                     0
# Offense Start DateTime      1892
# Offense End DateTime      486374
# Report DateTime                0
# Group A B                      0
# Crime Against Category         0
# Offense Parent Group           0
# Offense                        0
# Offense Code                   0
# Precinct                       7
# Sector                         7
# Beat                           7
# MCPP                          27
# 100 Block Address          50852
# Longitude                      0
# Latitude                       0
# dtype: int64

# %%
Crime = Crime.dropna(subset = ['Offense Start DateTime','Offense End DateTime', 'Precinct', 'Sector', 'Beat', 'MCPP', '100 Block Address'])

# %%
Crime
# Out:
#         Report Number   Offense ID  Offense Start DateTime  \
# 1         2020-044452  12605598696  02/03/2020 08:00:00 AM
# 2         2020-044465  12605567653  02/02/2020 08:30:00 PM
# 3         2020-044225  12605174036  02/05/2020 01:17:00 AM
# 6         2020-044104  12605029468  02/04/2020 08:30:00 PM
# 9         2020-044065  12605008517  02/04/2020 09:00:00 PM
# ...               ...          ...                     ...
# 1150132   2023-301987  52633318986  10/11/2023 12:00:00 AM
# 1150138   2019-223685   8335129478  04/01/2019 11:52:58 AM
# 1150140   2014-122134   7699116275  03/20/2014 10:30:00 AM
# 1150142   2013-227022   7682354808  06/26/2013 11:00:00 AM
# 1150145   2010-064656   7686420892  02/25/2010 06:00:00 PM
#
#            Offense End DateTime         Report DateTime Group A B  \
# 1        02/04/2020 08:00:00 AM  02/05/2020 10:06:28 AM         A
# 2        02/02/2020 09:30:00 PM  02/05/2020 09:39:33 AM         A
# ...

# %%
Crime.to_csv('Crime2.csv', index=False)

# %%
merged_df = pd.merge(Crime, SPD, on = 'Date')

# %%
Crime['Date'] = pd.to_datetime(Crime['Offense Start DateTime']).dt.date
Crime['Time'] = pd.to_datetime(Crime['Offense Start DateTime']).dt.time

# %%
SPD['Date'] = pd.to_datetime(SPD['Date / Time']).dt.date
SPD['Time'] = pd.to_datetime(SPD['Date / Time']).dt.time

# %%
SPD
# Out:
#           Date / Time  Longitude  Latitude     City            Rank  \
# 0     3/21/2005 18:28   -122.274    47.544  Seattle         Officer
# 1     6/20/2005 11:30   -122.336    47.615  Seattle         Officer
# 2     6/20/2005 12:30   -122.336    47.615  Seattle         Officer
# 3      7/8/2005 13:48   -122.311    47.613  Seattle         Officer
# 4      9/23/2005 2:40   -122.346    47.612  Seattle         Officer
# ..                ...        ...       ...      ...             ...
# 112  12/31/2018 17:01   -122.345    47.699  Seattle  POLICE OFFICER
# 113  10/24/2019 10:34   -122.387    47.582  Seattle  POLICE OFFICER
# 114  10/24/2019 10:34   -122.387    47.582  Seattle  POLICE OFFICER
# 115   1/22/2020 15:30   -122.344    47.614  Seattle  POLICE OFFICER
# 116    1/22/2020 0:00   -122.344    47.614  Seattle  POLICE OFFICER
#
#     Officer Gender     Officer Race Years of SPD Service Officer Injured  \
# 0             Male            White                   20              No
# ...

# %%
Crime
# Out:
#         Report Number   Offense ID  Offense Start DateTime  \
# 1         2020-044452  12605598696  02/03/2020 08:00:00 AM
# 2         2020-044465  12605567653  02/02/2020 08:30:00 PM
# 3         2020-044225  12605174036  02/05/2020 01:17:00 AM
# 6         2020-044104  12605029468  02/04/2020 08:30:00 PM
# 9         2020-044065  12605008517  02/04/2020 09:00:00 PM
# ...               ...          ...                     ...
# 1150132   2023-301987  52633318986  10/11/2023 12:00:00 AM
# 1150138   2019-223685   8335129478  04/01/2019 11:52:58 AM
# 1150140   2014-122134   7699116275  03/20/2014 10:30:00 AM
# 1150142   2013-227022   7682354808  06/26/2013 11:00:00 AM
# 1150145   2010-064656   7686420892  02/25/2010 06:00:00 PM
#
#            Offense End DateTime         Report DateTime Group A B  \
# 1        02/04/2020 08:00:00 AM  02/05/2020 10:06:28 AM         A
# 2        02/02/2020 09:30:00 PM  02/05/2020 09:39:33 AM         A
# ...

# %%
merged_df
# Out:
#      Report Number   Offense ID  Offense Start DateTime  \
# 0      2020-038899  12597533695  10/24/2019 12:01:00 AM
# 1      2020-038899  12597533695  10/24/2019 12:01:00 AM
# 2      2020-901445  12470931083  01/22/2020 11:25:00 AM
# 3      2020-901445  12470931083  01/22/2020 11:25:00 AM
# 4      2020-901386  12455035332  01/22/2020 12:00:00 AM
# ...            ...          ...                     ...
# 9354   2024-936574  58231238132  07/01/2014 01:00:00 AM
# 9355   2020-028639  12238246833  01/22/2020 12:00:00 AM
# 9356   2020-028639  12238246833  01/22/2020 12:00:00 AM
# 9357   2019-396531  11310815280  10/24/2019 11:54:00 AM
# 9358   2019-396531  11310815280  10/24/2019 11:54:00 AM
#
#         Offense End DateTime         Report DateTime Group A B  \
# 0     01/29/2020 12:01:00 AM  01/31/2020 09:43:13 PM         A
# 1     01/29/2020 12:01:00 AM  01/31/2020 09:43:13 PM         A
# 2     01/28/2020 04:45:00 PM  01/29/2020 01:42:40 PM         A
# ...

# %%
merged_df.to_csv('Team1_dataset.csv', index=False)
